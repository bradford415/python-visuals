# %% [markdown]
# # Python Visuals
# A collection of useful or cool looking Python visuals for quick reference. Graphs and plots will be added as I come across them.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Loading in datasets

# %%
cluster_time_series_df = pd.read_csv("datasets/Mtr_A17Shoot_DTW-DPGP-EXP.csv")

# %% [markdown]
# ## General

# %% [markdown]
# ### Count Plot
# Shows the count of labels in a specified column

# %%
# Count of each label 
fig, ax = plt.subplots(figsize=(20,7.5))
sns.countplot(x='Cluster', data=cluster_time_series_df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Time Series
